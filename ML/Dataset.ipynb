# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh0405/VIThack20-Covid19Website/blob/Task4/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
df=pd.read_csv("covid19india.csv")
df1=pd.read_csv("covid19india.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patientId       27891 non-null  int64
#  1   reportedOn      27891 non-null  object
#  2   onsetEstimate   0 non-null      float64
#  3   ageEstimate     2346 non-null   object
#  4   gender          5313 non-null   object
#  5   city            2350 non-null   object
#  6   district        21051 non-null  object
#  7   state           27890 non-null  object
#  8   status          27891 non-null  object
#  9   notes           26555 non-null  object
#  10  contractedFrom  1638 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 2.3+ MB

# %%
df.head()
# Out:
#    patientId  ... contractedFrom
# 0          1  ...            NaN
# 1          2  ...            NaN
# 2          3  ...            NaN
# 3          4  ...            NaN
# 4          5  ...            NaN
#
# [5 rows x 11 columns]

# %%
df['onsetEstimate'].value_counts().head()
# Out:
# Series([], Name: onsetEstimate, dtype: int64)

# %%
df['patientId'].value_counts()
# Out:
# 2047     1
# 3371     1
# 15629    1
# 9486     1
# 11535    1
#         ..
# 17053    1
# 23198    1
# 21151    1
# 10928    1
# 2049     1
# Name: patientId, Length: 27891, dtype: int64

# %%
df['ageEstimate'].value_counts()
# Out:
# 35     89
# 32     74
# 40     63
# 30     60
# 50     60
#        ..
# 92      1
# 98      1
# 88      1
# 1.5     1
# 0.3     1
# Name: ageEstimate, Length: 92, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# male      3547
# female    1766
# Name: gender, dtype: int64

# %%
df.describe()
# Out:
#           patientId  onsetEstimate
# count  27891.000000            0.0
# mean   13946.000000            NaN
# std     8051.582515            NaN
# min        1.000000            NaN
# 25%     6973.500000            NaN
# 50%    13946.000000            NaN
# 75%    20918.500000            NaN
# max    27891.000000            NaN

# %%
df.isnull()
# Out:
#        patientId  reportedOn  onsetEstimate  ...  status  notes  contractedFrom
# 0          False       False           True  ...   False  False            True
# 1          False       False           True  ...   False  False            True
# 2          False       False           True  ...   False  False            True
# 3          False       False           True  ...   False  False            True
# 4          False       False           True  ...   False  False            True
# ...          ...         ...            ...  ...     ...    ...             ...
# 27886      False       False           True  ...   False  False            True
# 27887      False       False           True  ...   False  False            True
# 27888      False       False           True  ...   False  False            True
# 27889      False       False           True  ...   False  False            True
# 27890      False       False           True  ...   False  False            True
#
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
df.drop('onsetEstimate',axis=1,inplace=True)
df.drop('contractedFrom',axis=1,inplace=True)
df.drop('notes',axis=1,inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# for col in df.columns:
#   df[col]=str(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    27891 non-null  int64
#  1   reportedOn   27891 non-null  object
#  2   ageEstimate  2346 non-null   object
#  3   gender       5313 non-null   object
#  4   city         2350 non-null   object
#  5   district     21051 non-null  object
#  6   state        27890 non-null  object
#  7   status       27891 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.7+ MB

# %%
# LabEn=LabelEncoder();
# for col in df.columns:
#     df[col] = LabEn.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27891 entries, 0 to 27890
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    27891 non-null  int64
#  1   reportedOn   27891 non-null  object
#  2   ageEstimate  2346 non-null   object
#  3   gender       5313 non-null   object
#  4   city         2350 non-null   object
#  5   district     21051 non-null  object
#  6   state        27890 non-null  object
#  7   status       27891 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.7+ MB

# %%
df.head(50)
# Out:
#     patientId  reportedOn  ...              state        status
# 0           1  30/01/2020  ...             Kerala     Recovered
# 1           2  02/02/2020  ...             Kerala     Recovered
# 2           3  03/02/2020  ...             Kerala     Recovered
# 3           4  02/03/2020  ...              Delhi     Recovered
# 4           5  02/03/2020  ...          Telangana     Recovered
# 5           6  03/03/2020  ...          Rajasthan     Recovered
# 6           7  04/03/2020  ...            Haryana     Recovered
# 7           8  04/03/2020  ...            Haryana     Recovered
# 8           9  04/03/2020  ...            Haryana     Recovered
# 9          10  04/03/2020  ...            Haryana     Recovered
# 10         11  04/03/2020  ...            Haryana     Recovered
# 11         12  04/03/2020  ...            Haryana     Recovered
# 12         13  04/03/2020  ...            Haryana     Recovered
# 13         14  04/03/2020  ...            Haryana     Recovered
# ...

# %%
# df.isnull().values()

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 0 to 26766
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    1084 non-null   int64
#  1   reportedOn   1084 non-null   object
#  2   ageEstimate  1084 non-null   object
#  3   gender       1084 non-null   object
#  4   city         1084 non-null   object
#  5   district     1084 non-null   object
#  6   state        1084 non-null   object
#  7   status       1084 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 76.2+ KB

# %%
df
# Out:
#        patientId  reportedOn ageEstimate  ...    district       state        status
# 0              1  30/01/2020          20  ...    Thrissur      Kerala     Recovered
# 3              4  02/03/2020          45  ...  East Delhi       Delhi     Recovered
# 4              5  02/03/2020          24  ...   Hyderabad   Telangana     Recovered
# 5              6  03/03/2020          69  ...    Italians   Rajasthan     Recovered
# 20            21  04/03/2020          70  ...    Italians   Rajasthan     Recovered
# ...          ...         ...         ...  ...         ...         ...           ...
# 26481      26482  26/04/2020          60  ...   Gopalganj       Bihar  Hospitalized
# 26482      26483  26/04/2020          50  ...   Gopalganj       Bihar  Hospitalized
# 26483      26484  26/04/2020          60  ...   Gopalganj       Bihar  Hospitalized
# 26765      26766  26/04/2020          26  ...  Chandigarh  Chandigarh  Hospitalized
# ...

# %%
# df.ageEstimate = pd.Categorical(df.ageEstimate)

# %%
# df['ageEstimate'] = df.ageEstimate.cat.codes

# %%
df.gender = pd.Categorical(df.gender)
df['gender'] = df.gender.cat.codes

# %%
df.city = pd.Categorical(df.city)
df['city'] = df.city.cat.codes

df.district = pd.Categorical(df.district)
df['district'] = df.district.cat.codes

df.state = pd.Categorical(df.state)
df['state'] = df.state.cat.codes


df.status = pd.Categorical(df.status)
df['status'] = df.status.cat.codes

# %%
df
# Out:
#        patientId  reportedOn ageEstimate  gender  city  district  state  status
# 0              1  30/01/2020          20       0   384       131     13       2
# 3              4  02/03/2020          45       1   103        33      5       2
# 4              5  02/03/2020          24       1   146        46     24       2
# 5              6  03/03/2020          69       1   153        49     22       2
# 20            21  04/03/2020          70       0   153        49     22       2
# ...          ...         ...         ...     ...   ...       ...    ...     ...
# 26481      26482  26/04/2020          60       1   350        42      2       1
# 26482      26483  26/04/2020          50       0   317        42      2       1
# 26483      26484  26/04/2020          60       0    50        42      2       1
# 26765      26766  26/04/2020          26       0   357        23      3       1
# 26766      26767  26/04/2020          25       1   358        23      3       1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1084 entries, 0 to 26766
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   patientId    1084 non-null   int64
#  1   reportedOn   1084 non-null   object
#  2   ageEstimate  1084 non-null   object
#  3   gender       1084 non-null   int8
#  4   city         1084 non-null   int16
#  5   district     1084 non-null   int16
#  6   state        1084 non-null   int8
#  7   status       1084 non-null   int8
# dtypes: int16(2), int64(1), int8(3), object(2)
# memory usage: 41.3+ KB

# %%
dftrain=pd.read_csv("covid19india.csv")
dftrain.drop('onsetEstimate',axis=1,inplace=True)
dftrain.drop('contractedFrom',axis=1,inplace=True)
dftrain.drop('notes',axis=1,inplace=True)

dftrain.city = pd.Categorical(dftrain.city)
dftrain['city'] = dftrain.city.cat.codes

dftrain.district = pd.Categorical(dftrain.district)
dftrain['district'] = dftrain.district.cat.codes

dftrain.state = pd.Categorical(dftrain.state)
dftrain['state'] = dftrain.state.cat.codes


dftrain.status = pd.Categorical(dftrain.status)
dftrain['status'] = dftrain.status.cat.codes
dftrain.head(10)
# Out:
#    patientId  reportedOn ageEstimate  gender  city  district  state  status
# 0          1  30/01/2020          20  female   471       406     15       3
# 1          2  02/02/2020         NaN     NaN    11         8     15       3
# 2          3  03/02/2020         NaN     NaN   212       206     15       3
# 3          4  02/03/2020          45    male   122       111      7       3
# 4          5  02/03/2020          24    male   169       158     27       3
# 5          6  03/03/2020          69    male   178       163     25       3
# 6          7  04/03/2020          55     NaN   151       163     10       3
# 7          8  04/03/2020          55     NaN   151       163     10       3
# 8          9  04/03/2020          55     NaN   151       163     10       3
# 9         10  04/03/2020          55     NaN   151       163     10       3
